# %%
import pandas as pd

# %%
sp_list = pd.read_html(r'https://brains.florianmilz.com/ucdb/sony/fx3')

# %%
sp_list[0]
# Out:
#     sensor mode            resolution               codec sampling framerate  \
# 0   Full Format  4K UHD (3840 x 2160)  XAVC HS 4K (H.265)    4:2:2      120p
# 1   Full Format  4K UHD (3840 x 2160)  XAVC HS 4K (H.265)    4:2:2      100p
# 2   Full Format  4K UHD (3840 x 2160)  XAVC HS 4K (H.265)    4:2:2       60p
# 3   Full Format  4K UHD (3840 x 2160)  XAVC HS 4K (H.265)    4:2:2       50p
# 4   Full Format  4K UHD (3840 x 2160)  XAVC HS 4K (H.265)    4:2:2       30p
# 5   Full Format  4K UHD (3840 x 2160)  XAVC HS 4K (H.265)    4:2:2       25p
# 6   Full Format  4K UHD (3840 x 2160)  XAVC HS 4K (H.265)    4:2:2       24p
# 7   Full Format  4K UHD (3840 x 2160)  XAVC HS 4K (H.265)    4:2:2       60p
# 8   Full Format  4K UHD (3840 x 2160)  XAVC HS 4K (H.265)    4:2:2       50p
# 9   Full Format  4K UHD (3840 x 2160)  XAVC HS 4K (H.265)    4:2:2       30p
# 10  Full Format  4K UHD (3840 x 2160)  XAVC HS 4K (H.265)    4:2:2       25p
# ...

# %%
sp_list[1]
# Out:
#     sensor mode        resolution        codec sampling framerate    160GB  \
# 0   Full Format  HD (1920 x 1080)    XAVC S HD    4:2:2      240p  365 min
# 1   Full Format  HD (1920 x 1080)    XAVC S HD    4:2:2      200p  365 min
# 2   Full Format  HD (1920 x 1080)    XAVC S HD    4:2:2      120p  365 min
# 3   Full Format  HD (1920 x 1080)    XAVC S HD    4:2:2      100p  365 min
# 4   Full Format  HD (1920 x 1080)    XAVC S HD    4:2:2       60p  365 min
# ..          ...               ...          ...      ...       ...      ...
# 67    APS-C S35  HD (1920 x 1080)  XAVC S-I HD    4:2:2       60p   91 min
# 68    APS-C S35  HD (1920 x 1080)  XAVC S-I HD    4:2:2       50p  109 min
# 69    APS-C S35  HD (1920 x 1080)  XAVC S-I HD    4:2:2       30p  181 min
# 70    APS-C S35  HD (1920 x 1080)  XAVC S-I HD    4:2:2       25p  215 min
# 71    APS-C S35  HD (1920 x 1080)  XAVC S-I HD    4:2:2       24p  225 min
#
# ...

# %%
x = sp_list[0]['datarate'].to_list()
for i in x:
    print(i, end='\n')
# Out:
# 280 Mb/s
# 280 Mb/s
# 200 Mb/s
# 200 Mb/s
# 100 Mb/s
# 100 Mb/s
# 100 Mb/s
# 100 Mb/s
# 100 Mb/s
# 50 Mb/s
# 50 Mb/s
# 50 Mb/s
# 200 Mb/s
# 200 Mb/s
# 150 Mb/s
# 150 Mb/s
# 100 Mb/s
# 100 Mb/s
# 100 Mb/s
# 75 Mb/s
# 75 Mb/s
# 50 Mb/s
# 50 Mb/s
# 50 Mb/s
# 45 Mb/s
# 45 Mb/s
# 30 Mb/s
# 30 Mb/s
# 30 Mb/s
# 280 Mb/s
# 280 Mb/s
# 200 Mb/s
# 200 Mb/s
# 140 Mb/s
# 140 Mb/s
# 100 Mb/s
# 200 Mb/s
# 200 Mb/s
# 150 Mb/s
# 150 Mb/s
# 100 Mb/s
# 100 Mb/s
# 100 Mb/s
# 60 Mb/s
# 60 Mb/s
# 60 Mb/s
# 600 Mb/s
# 500 Mb/s
# 300 Mb/s
# 250 Mb/s
# 240 Mb/s
